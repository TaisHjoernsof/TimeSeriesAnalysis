# %%
import pandas as pd
data = pd.read_csv("data/transformer_data.csv")

# %%
data
# Out:
#      time          Y         Ta      S          I
# 0       1  23.496733   7.083333    0.0  15.899541
# 1       2  22.720333   7.116667    0.0  15.861768
# 2       3  22.052700   7.216667    0.0  16.121469
# 3       4  21.538050   7.250000    0.0  15.447628
# 4       5  20.995033   7.316667    0.0  16.258319
# ..    ...        ...        ...    ...        ...
# 163   164  31.510183  14.350000  157.5  16.000643
# 164   165  30.037760  12.166667   29.0  16.005937
# 165   166  28.530450  10.283333    0.0  16.427983
# 166   167  27.118660   8.700000    0.0  16.370292
# 167   168  25.956717   7.600000    0.0  16.007713
#
# [168 rows x 5 columns]

# %%
data.plot(x='time', y='Y')
# Out:
# <Axes: xlabel='time'>

# %%
data.describe().round(2)
# Out:
#          time       Y      Ta       S       I
# count  168.00  168.00  168.00  168.00  168.00
# mean    84.50   27.65   10.02  214.43   18.18
# std     48.64    5.46    2.92  259.45    3.66
# min      1.00   19.83    4.52    0.00   14.39
# 25%     42.75   23.25    7.87    0.00   15.64
# 50%     84.50   26.07    9.75   65.42   16.37
# 75%    126.25   32.20   12.00  410.25   21.21
# max    168.00   38.92   17.47  755.83   25.36

# %%
import pandas as pd


# Compute correlation matrix for key variables
corr_matrix = data[['Y', 'Ta', 'S', 'I']].corr()

# Optionally round and display
print(corr_matrix.round(2))
# Out:
#        Y    Ta     S     I
# Y   1.00  0.78  0.80  0.38
# Ta  0.78  1.00  0.71  0.16
# S   0.80  0.71  1.00  0.63
# I   0.38  0.16  0.63  1.00
